# %%
import os, time, warnings
import numpy as np
import torch
import torch.nn as nn
import matplotlib
matplotlib.use("Agg")          
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.patches import Ellipse
import pandas as pd
from IPython.display import display, Image
import io

warnings.filterwarnings("ignore")
torch.manual_seed(42)
np.random.seed(42)

# 0.  Global configuration
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

X_MIN, X_MAX = -6.0, 15.0
Y_MIN, Y_MAX = -6.0,  6.0
A_ELLIPSE, B_ELLIPSE = 1.0, 0.5

RE_TRUE          = 100.0
HIDDEN_LAYERS    = 6
HIDDEN_NODES     = 64
EPOCHS_FORWARD   = 3000
EPOCHS_INVERSE   = 4000
LR               = 1e-3
LAMBDA_PDE       = 1.0
LAMBDA_BC        = 10.0
LAMBDA_DATA      = 10.0
CONVERGENCE_TOL  = 0.10

# helper: show a matplotlib figure inline 
def show_figure(fig, title=""):
    """Render fig to a PNG buffer and display it inline."""
    buf = io.BytesIO()
    fig.savefig(buf, format="png", dpi=120, bbox_inches="tight",
                facecolor=fig.get_facecolor())
    buf.seek(0)
    if title:
        print(f"\n{'─'*60}")
        print(f"  {title}")
        print(f"{'─'*60}")
    display(Image(data=buf.read()))
    plt.close(fig)

# 1.  Helper utilities
def inside_ellipse(x, y, a=A_ELLIPSE, b=B_ELLIPSE):
    return (x / a)**2 + (y / b)**2 < 1.0

def sample_domain(n, rng=None):
    if rng is None:
        rng = np.random.default_rng(42)
    pts = []
    while len(pts) < n:
        x = rng.uniform(X_MIN, X_MAX, n * 3)
        y = rng.uniform(Y_MIN, Y_MAX, n * 3)
        mask = ~inside_ellipse(x, y)
        pts.extend(zip(x[mask], y[mask]))
    return np.array(pts[:n], dtype=np.float32)

def sample_wake(n, rng=None):
    """Wake-clustered sampling: concentrate points behind the ellipse."""
    if rng is None:
        rng = np.random.default_rng(42)
    pts = []
    n_wake = int(n * 0.7)          # 70 % in the wake region
    n_rest = n - n_wake
    # Wake region: x in [1, 8], |y| < 2
    while len(pts) < n_wake:
        x = rng.uniform(1.0, 8.0, n_wake * 4)
        y = rng.uniform(-2.0, 2.0, n_wake * 4)
        mask = ~inside_ellipse(x, y)
        pts.extend(zip(x[mask], y[mask]))
    while len(pts) < n:
        x = rng.uniform(X_MIN, X_MAX, n_rest * 4)
        y = rng.uniform(Y_MIN, Y_MAX, n_rest * 4)
        mask = ~inside_ellipse(x, y)
        pts.extend(zip(x[mask], y[mask]))
    return np.array(pts[:n], dtype=np.float32)

def to_tensor(arr, grad=False):
    return torch.tensor(arr, dtype=torch.float32,
                        device=DEVICE, requires_grad=grad)

def draw_ellipse_patch(ax, **kwargs):
    ax.add_patch(Ellipse((0, 0), 2*A_ELLIPSE, 2*B_ELLIPSE,
                         color="white", zorder=5, **kwargs))
    ax.add_patch(Ellipse((0, 0), 2*A_ELLIPSE, 2*B_ELLIPSE,
                         fill=False, edgecolor="k", lw=0.8, zorder=6))

# 2.  Neural-network architecture
class PINN(nn.Module):
    def __init__(self, layers, nodes, inverse=False, re_init=50.0):
        super().__init__()
        self.inverse = inverse
        net = [nn.Linear(2, nodes)]
        for _ in range(layers - 1):
            net += [nn.Tanh(), nn.Linear(nodes, nodes)]
        net += [nn.Tanh(), nn.Linear(nodes, 3)]
        self.net = nn.Sequential(*net)
        for m in self.net.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.zeros_(m.bias)
        if inverse:
            self._log_nu = nn.Parameter(
                torch.tensor(np.log(1.0 / re_init), dtype=torch.float32))

    def forward(self, xy):
        return self.net(xy)

    @property
    def nu(self):
        return torch.exp(self._log_nu)

    @property
    def Re(self):
        return 1.0 / self.nu

# 3.  PDE residuals
def ns_residuals(model, xy, nu_override=None):
    xy = xy.clone().requires_grad_(True)
    out = model(xy)
    u, v, p = out[:, 0:1], out[:, 1:2], out[:, 2:3]
    nu = nu_override if nu_override is not None else model.nu

    def grad(f, x):
        return torch.autograd.grad(f, x,
                                   grad_outputs=torch.ones_like(f),
                                   create_graph=True,
                                   retain_graph=True)[0]

    gu = grad(u, xy);  u_x, u_y = gu[:, 0:1], gu[:, 1:2]
    gv = grad(v, xy);  v_x, v_y = gv[:, 0:1], gv[:, 1:2]
    gp = grad(p, xy);  p_x, p_y = gp[:, 0:1], gp[:, 1:2]
    u_xx = grad(u_x, xy)[:, 0:1];  u_yy = grad(u_y, xy)[:, 1:2]
    v_xx = grad(v_x, xy)[:, 0:1];  v_yy = grad(v_y, xy)[:, 1:2]

    cont  = u_x + v_y
    mom_x = u*u_x + v*u_y + p_x - nu*(u_xx + u_yy)
    mom_y = u*v_x + v*v_y + p_y - nu*(v_xx + v_yy)
    return cont, mom_x, mom_y

# 4.  Boundary-condition losses
def bc_loss(model, nu_fixed=None):
    losses = []
    y_in  = torch.linspace(Y_MIN, Y_MAX, 60, device=DEVICE).unsqueeze(1)
    x_in  = torch.full_like(y_in, X_MIN)
    out   = model(torch.cat([x_in, y_in], 1))
    losses += [torch.mean((out[:,0]-1.0)**2), torch.mean(out[:,1]**2)]

    y_out = torch.linspace(Y_MIN, Y_MAX, 60, device=DEVICE).unsqueeze(1)
    x_out = torch.full_like(y_out, X_MAX)
    out_o = model(torch.cat([x_out, y_out], 1))
    losses.append(torch.mean(out_o[:,2]**2))

    x_tb = torch.linspace(X_MIN, X_MAX, 80, device=DEVICE).unsqueeze(1)
    for yy in [torch.full_like(x_tb, Y_MAX), torch.full_like(x_tb, Y_MIN)]:
        out_tb = model(torch.cat([x_tb, yy], 1))
        losses.append(torch.mean(out_tb[:,1]**2))

    theta = torch.linspace(0, 2*np.pi, 120, device=DEVICE)
    x_e = A_ELLIPSE * torch.cos(theta).unsqueeze(1)
    y_e = B_ELLIPSE * torch.sin(theta).unsqueeze(1)
    out_e = model(torch.cat([x_e, y_e], 1))
    losses += [torch.mean(out_e[:,0]**2), torch.mean(out_e[:,1]**2)]
    return sum(losses)

# 5. Forward PINN
def train_forward_pinn(re_true, n_col=3000, epochs=EPOCHS_FORWARD, verbose=True):
    nu_fixed = torch.tensor(1.0/re_true, dtype=torch.float32, device=DEVICE)
    model = PINN(HIDDEN_LAYERS, HIDDEN_NODES, inverse=False).to(DEVICE)
    opt   = torch.optim.Adam(model.parameters(), lr=LR)
    sched = torch.optim.lr_scheduler.StepLR(opt, step_size=5000, gamma=0.5)

    col_np = sample_domain(n_col)
    xy_col = to_tensor(col_np)

    history = []
    t0 = time.time()
    for ep in range(1, epochs+1):
        model.train(); opt.zero_grad()
        cont, mx, my = ns_residuals(model, xy_col, nu_override=nu_fixed)
        loss_pde = torch.mean(cont**2 + mx**2 + my**2)
        loss_bc  = bc_loss(model, nu_fixed=nu_fixed)
        loss     = LAMBDA_PDE*loss_pde + LAMBDA_BC*loss_bc
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step(); sched.step()
        history.append(loss.item())
        if verbose and ep % 1000 == 0:
            print(f"  [Forward Re={re_true:.0f}] ep {ep:>5d}  "
                  f"loss={loss.item():.4e}  "
                  f"pde={loss_pde.item():.4e}  "
                  f"bc={loss_bc.item():.4e}  "
                  f"t={time.time()-t0:.1f}s")
    return model, history

# 6.  Inverse PINN
def train_inverse_pinn(obs_xy, obs_uvp,
                       n_col=3000, epochs=EPOCHS_INVERSE,
                       re_init=50.0, verbose=True, label=""):
    model = PINN(HIDDEN_LAYERS, HIDDEN_NODES,
                 inverse=True, re_init=re_init).to(DEVICE)
    opt   = torch.optim.Adam(model.parameters(), lr=LR)
    sched = torch.optim.lr_scheduler.StepLR(opt, step_size=6000, gamma=0.5)

    col_np = sample_domain(n_col)
    xy_col  = to_tensor(col_np)
    xy_obs  = to_tensor(obs_xy)
    uvp_obs = to_tensor(obs_uvp)

    hist = {k: [] for k in ["total","pde","bc","data","re"]}
    t0 = time.time()
    for ep in range(1, epochs+1):
        model.train(); opt.zero_grad()
        pred_obs  = model(xy_obs)
        loss_data = torch.mean((pred_obs - uvp_obs)**2)
        cont, mx, my = ns_residuals(model, xy_col)
        loss_pde  = torch.mean(cont**2 + mx**2 + my**2)
        loss_bc   = bc_loss(model)
        loss      = LAMBDA_DATA*loss_data + LAMBDA_PDE*loss_pde + LAMBDA_BC*loss_bc
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step(); sched.step()
        hist["total"].append(loss.item())
        hist["pde"].append(loss_pde.item())
        hist["bc"].append(loss_bc.item())
        hist["data"].append(loss_data.item())
        hist["re"].append(model.Re.item())
        if verbose and ep % 1000 == 0:
            print(f"  [{label}] ep {ep:>5d}  "
                  f"total={loss.item():.4e}  "
                  f"Re_pred={model.Re.item():.2f}  "
                  f"t={time.time()-t0:.1f}s")
    return model, model.Re.item(), hist


# 7.  Observations & grid
def generate_observations(fwd_model, pts_xy):
    fwd_model.eval()
    with torch.no_grad():
        return fwd_model(to_tensor(pts_xy)).cpu().numpy()

def build_eval_grid(nx=200, ny=80):
    xv = np.linspace(X_MIN, X_MAX, nx)
    yv = np.linspace(Y_MIN, Y_MAX, ny)
    XX, YY = np.meshgrid(xv, yv)
    mask   = inside_ellipse(XX, YY)
    xy_flat = np.stack([XX.ravel(), YY.ravel()], 1).astype(np.float32)
    return XX, YY, mask, xy_flat

def predict_grid(model, xy_flat, bs=4096):
    model.eval(); preds = []
    with torch.no_grad():
        for i in range(0, len(xy_flat), bs):
            preds.append(model(to_tensor(xy_flat[i:i+bs])).cpu().numpy())
    return np.vstack(preds)

# 9.  Plotting helpers  ── inline display instead of saving files
CMAP_U = "RdBu_r"; CMAP_V = "seismic"; CMAP_P = "coolwarm"

def plot_flow_fields(model, title_suffix, re_label=""):
    XX, YY, mask, xy_flat = build_eval_grid()
    uvp = predict_grid(model, xy_flat)
    UU = uvp[:,0].reshape(XX.shape); UU[mask] = np.nan
    VV = uvp[:,1].reshape(XX.shape); VV[mask] = np.nan
    PP = uvp[:,2].reshape(XX.shape); PP[mask] = np.nan

    fig = plt.figure(figsize=(18, 14))
    fig.patch.set_facecolor("#0d0d1a")
    gs  = gridspec.GridSpec(2, 2, figure=fig, hspace=0.38, wspace=0.28)
    titles = ["Streamwise Velocity  $u$", "Cross-stream Velocity  $v$",
              "Pressure  $p$", "Streamlines"]
    cmaps  = [CMAP_U, CMAP_V, CMAP_P, None]
    fields = [UU, VV, PP, None]

    for idx, (ttl, cmap, fld) in enumerate(zip(titles, cmaps, fields)):
        ax = fig.add_subplot(gs[idx//2, idx%2])
        ax.set_facecolor("#0d0d1a")
        for sp in ax.spines.values(): sp.set_color("#444")

        if fld is not None:
            vmax = np.nanpercentile(np.abs(fld), 98)
            vmin = -vmax if cmap in [CMAP_V, CMAP_P] else 0
            cf = ax.contourf(XX, YY, fld, levels=50, cmap=cmap, vmin=vmin, vmax=vmax)
            cb = fig.colorbar(cf, ax=ax, fraction=0.025, pad=0.02)
            cb.ax.tick_params(colors="white", labelsize=7)
        else:
            speed = np.sqrt(UU**2 + VV**2)
            sp2   = np.where(np.isnan(speed), 0, speed)
            ax.contourf(XX, YY, sp2, levels=40, cmap="magma", alpha=0.7)
            seed_x = np.full(20, X_MIN + 0.05)
            seed_y = np.linspace(Y_MIN + 0.3, Y_MAX - 0.3, 20)
            ax.streamplot(XX[0], YY[:,0],
                          np.where(np.isnan(UU), 0, UU),
                          np.where(np.isnan(VV), 0, VV),
                          color="white", linewidth=0.5, density=2,
                          start_points=np.c_[seed_x, seed_y], arrowsize=0.5)

        draw_ellipse_patch(ax)
        ax.set_xlim(X_MIN, X_MAX); ax.set_ylim(Y_MIN, Y_MAX)
        ax.set_title(ttl, color="white", fontsize=10, pad=6)
        ax.set_xlabel("x", color="#aaa", fontsize=8)
        ax.set_ylabel("y", color="#aaa", fontsize=8)
        ax.tick_params(colors="#aaa", labelsize=7)

    sup = f"Problem 3 — Inverse PINN  |  {title_suffix}"
    if re_label: sup += f"  |  {re_label}"
    fig.suptitle(sup, color="white", fontsize=12, y=0.97)
    show_figure(fig, title_suffix)


def plot_re_convergence(n_list, re_list, err_list):
    fig, ax1 = plt.subplots(figsize=(9, 5))
    fig.patch.set_facecolor("#0d0d1a"); ax1.set_facecolor("#0d0d1a")
    color_re = "#f5a623"; color_err = "#7ed6df"

    ax1.plot(n_list, re_list, "o-", color=color_re, lw=2, ms=7,
             label=f"Recovered Re  (True={RE_TRUE:.0f})")
    ax1.axhline(RE_TRUE, color=color_re, ls="--", lw=1, alpha=0.5)
    ax1.set_xlabel("N  (number of observation points)", color="#ccc", fontsize=11)
    ax1.set_ylabel("Recovered Re", color=color_re, fontsize=11)
    ax1.tick_params(axis="y", colors=color_re); ax1.tick_params(axis="x", colors="#ccc")
    ax1.set_title("Inverse PINN — Reynolds Number Recovery vs N",
                  color="white", fontsize=13)
    for sp in ax1.spines.values(): sp.set_color("#444")

    ax2 = ax1.twinx(); ax2.set_facecolor("#0d0d1a")
    ax2.plot(n_list, err_list, "s--", color=color_err, lw=2, ms=7, label="% Error")
    ax2.axhline(10.0, color=color_err, ls=":", lw=1, alpha=0.6, label="10% threshold")
    ax2.set_ylabel("Percentage Error (%)", color=color_err, fontsize=11)
    ax2.tick_params(axis="y", colors=color_err)
    for sp in ax2.spines.values(): sp.set_color("#444")

    lines1, lbl1 = ax1.get_legend_handles_labels()
    lines2, lbl2 = ax2.get_legend_handles_labels()
    ax1.legend(lines1+lines2, lbl1+lbl2,
               facecolor="#1a1a2e", edgecolor="#444",
               labelcolor="white", fontsize=9, loc="upper right")
    fig.tight_layout()
    show_figure(fig, "Uniform Sampling: Re Convergence vs N")


def plot_sampling_comparison(results_uniform, results_wake):
    ns    = [r["N"]     for r in results_uniform]
    err_u = [r["error"] for r in results_uniform]
    err_w = [r["error"] for r in results_wake]

    fig, ax = plt.subplots(figsize=(9, 5))
    fig.patch.set_facecolor("#0d0d1a"); ax.set_facecolor("#0d0d1a")
    w  = 0.35; xs = np.arange(len(ns))
    ax.bar(xs - w/2, err_u, w, label="Uniform sampling",      color="#f5a623", alpha=0.85)
    ax.bar(xs + w/2, err_w, w, label="Wake-clustered sampling", color="#7ed6df", alpha=0.85)
    ax.axhline(10.0, color="white", ls="--", lw=1.2, label="10% convergence threshold")
    ax.set_xticks(xs); ax.set_xticklabels([str(n) for n in ns], color="#ccc")
    ax.tick_params(axis="y", colors="#ccc")
    ax.set_xlabel("N  (observation points)", color="#ccc", fontsize=11)
    ax.set_ylabel("% Error in recovered Re", color="#ccc", fontsize=11)
    ax.set_title("Uniform vs Wake-Clustered Sampling — Convergence Comparison",
                 color="white", fontsize=12)
    for sp in ax.spines.values(): sp.set_color("#444")
    ax.legend(facecolor="#1a1a2e", edgecolor="#444", labelcolor="white", fontsize=9)
    fig.tight_layout()
    show_figure(fig, "Sampling Strategy Comparison")


def plot_loss_history(history, re_true, label):
    ep = np.arange(1, len(history["total"]) + 1)
    fig, axes = plt.subplots(1, 2, figsize=(13, 4))
    fig.patch.set_facecolor("#0d0d1a")
    colors = {"total": "#f5a623", "pde": "#7ed6df",
              "bc": "#a29bfe", "data": "#fd79a8"}

    for ax, keys, title in [
        (axes[0], ["total","pde","bc","data"], "Loss Components"),
        (axes[1], ["re"], f"Recovered Re  (True={re_true:.0f})")
    ]:
        ax.set_facecolor("#0d0d1a")
        for sp in ax.spines.values(): sp.set_color("#444")
        ax.tick_params(colors="#ccc")
        for k in keys:
            lbl = "Re_pred" if k == "re" else k
            ax.semilogy(ep, history[k], lw=1.2,
                        color=colors.get(k, "#ffffff"), label=lbl)
        if "re" in keys:
            ax.set_yscale("linear")
            ax.axhline(re_true, color="white", ls="--", lw=1.0,
                       label=f"Re_true={re_true:.0f}")
        ax.set_xlabel("Epoch", color="#ccc")
        ax.set_title(title, color="white", fontsize=10)
        ax.legend(facecolor="#1a1a2e", edgecolor="#444",
                  labelcolor="white", fontsize=8)

    fig.suptitle(f"Training History — {label}", color="white", fontsize=12)
    fig.tight_layout()
    show_figure(fig, f"Loss History: {label}")


def plot_obs_location(obs_uniform, obs_wake):
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    fig.patch.set_facecolor("#0d0d1a")
    for ax, pts, title, color in [
        (axes[0], obs_uniform, "Uniform Sampling",       "#f5a623"),
        (axes[1], obs_wake,    "Wake-Clustered Sampling", "#7ed6df")
    ]:
        ax.set_facecolor("#0d0d1a")
        for sp in ax.spines.values(): sp.set_color("#444")
        ax.scatter(pts[:,0], pts[:,1], c=color, s=25, zorder=3, alpha=0.85)
        draw_ellipse_patch(ax)
        ax.set_xlim(X_MIN, X_MAX); ax.set_ylim(Y_MIN, Y_MAX)
        ax.set_title(title, color="white", fontsize=11)
        ax.set_xlabel("x", color="#aaa"); ax.set_ylabel("y", color="#aaa")
        ax.tick_params(colors="#aaa")
    fig.suptitle("Observation Point Locations", color="white", fontsize=13)
    fig.tight_layout()
    show_figure(fig, "Observation Point Locations")

# 10.  Main execution
def main():
    print("\n" + "="*65)
    print("  ME4222E — Problem 3: Inverse PINN")
    print(f"  True Reynolds number: Re = {RE_TRUE:.0f}")
    print("="*65)

    # Forward PINN 
    print("\n[A] Training forward PINN to generate synthetic observations...")
    fwd_model, fwd_hist = train_forward_pinn(RE_TRUE, epochs=EPOCHS_FORWARD)
    plot_flow_fields(fwd_model,
                     f"Forward PINN  Re={RE_TRUE:.0f}  (Ground Truth)",
                     re_label=f"Re={RE_TRUE:.0f}")

    # Uniform N-sweep 
    print("\n[B] Inverse PINN — N-sweep with UNIFORM sampling")
    rng_u = np.random.default_rng(7)
    sweep_results = []; converged_N_uniform = None

    for N in range(10, 110, 10):
        print(f"\n  N = {N} (uniform)")
        pts_xy  = sample_domain(N, rng=rng_u)
        pts_uvp = generate_observations(fwd_model, pts_xy)

        inv_model, re_rec, hist = train_inverse_pinn(
            pts_xy, pts_uvp, re_init=50.0,
            epochs=EPOCHS_INVERSE, verbose=True, label=f"Uniform N={N}")

        err = abs(re_rec - RE_TRUE) / RE_TRUE * 100
        sweep_results.append(dict(N=N, strategy="uniform",
                                  Re_rec=re_rec, error=err,
                                  final_loss=hist["total"][-1]))
        print(f"  >> N={N}  Re_rec={re_rec:.2f}  Error={err:.2f}%  "
              f"Loss={hist['total'][-1]:.4e}")

        # Loss history plot for every N
        plot_loss_history(hist, RE_TRUE, f"Uniform N={N}")

        if err <= CONVERGENCE_TOL*100 and converged_N_uniform is None:
            converged_N_uniform = N
            print(f"  *** CONVERGED at N={N} (uniform) ***")
            plot_flow_fields(inv_model,
                             f"Inverse PINN  Uniform  N={N}  Re_rec={re_rec:.1f}",
                             re_label=f"Re_rec={re_rec:.1f}")

    # Wake-clustered N-sweep 
    print("\n[C] Inverse PINN — N-sweep with WAKE-CLUSTERED sampling")
    rng_w = np.random.default_rng(13)
    wake_results = []; converged_N_wake = None

    for N in range(10, 110, 10):
        print(f"\n  N = {N} (wake-clustered)")
        pts_xy  = sample_wake(N, rng=rng_w)
        pts_uvp = generate_observations(fwd_model, pts_xy)

        inv_model_w, re_rec_w, hist_w = train_inverse_pinn(
            pts_xy, pts_uvp, re_init=50.0,
            epochs=EPOCHS_INVERSE, verbose=True, label=f"Wake N={N}")

        err_w = abs(re_rec_w - RE_TRUE) / RE_TRUE * 100
        wake_results.append(dict(N=N, strategy="wake",
                                 Re_rec=re_rec_w, error=err_w,
                                 final_loss=hist_w["total"][-1]))
        print(f"  >> N={N}  Re_rec={re_rec_w:.2f}  Error={err_w:.2f}%  "
              f"Loss={hist_w['total'][-1]:.4e}")

        plot_loss_history(hist_w, RE_TRUE, f"Wake N={N}")

        if err_w <= CONVERGENCE_TOL*100 and converged_N_wake is None:
            converged_N_wake = N
            print(f"  *** CONVERGED at N={N} (wake) ***")
            plot_flow_fields(inv_model_w,
                             f"Inverse PINN  Wake  N={N}  Re_rec={re_rec_w:.1f}",
                             re_label=f"Re_rec={re_rec_w:.1f}")

    # Summary plots 
    print("\n[D] Generating summary plots and tables...")

    n_u   = [r["N"]      for r in sweep_results]
    re_u  = [r["Re_rec"] for r in sweep_results]
    err_u = [r["error"]  for r in sweep_results]

    plot_re_convergence(n_u, re_u, err_u)
    plot_sampling_comparison(sweep_results, wake_results)

    obs_u_vis = sample_domain(converged_N_uniform or 40,
                               rng=np.random.default_rng(7))
    obs_w_vis = sample_wake(converged_N_wake or 30,
                             rng=np.random.default_rng(13))
    plot_obs_location(obs_u_vis, obs_w_vis)

    # Tables printed to terminal 
    print("\n" + "="*65)
    print("  TABLE 1 — Uniform Sampling: N vs Recovered Re")
    print("="*65)
    df_u = pd.DataFrame(sweep_results)[["N","Re_rec","error","final_loss","strategy"]]
    df_u.columns = ["N", "Recovered Re", "% Error", "Final Loss", "Strategy"]
    print(df_u.to_string(index=False, float_format=lambda x: f"{x:.4f}"))

    print("\n" + "="*65)
    print("  TABLE 2 — Wake-Clustered Sampling: N vs Recovered Re")
    print("="*65)
    df_w = pd.DataFrame(wake_results)[["N","Re_rec","error","final_loss","strategy"]]
    df_w.columns = ["N", "Recovered Re", "% Error", "Final Loss", "Strategy"]
    print(df_w.to_string(index=False, float_format=lambda x: f"{x:.4f}"))

    # Also render tables as styled DataFrames in notebook output
    print("\n[Rendered table — Uniform]")
    display(df_u.style.format({"Recovered Re": "{:.2f}", "% Error": "{:.2f}%",
                                "Final Loss": "{:.4e}"})
                       .highlight_min(subset=["% Error"], color="lightgreen")
                       .set_caption("Uniform Sampling Results"))

    print("\n[Rendered table — Wake-Clustered]")
    display(df_w.style.format({"Recovered Re": "{:.2f}", "% Error": "{:.2f}%",
                                "Final Loss": "{:.4e}"})
                       .highlight_min(subset=["% Error"], color="lightblue")
                       .set_caption("Wake-Clustered Sampling Results"))

    # Convergence summary 
    print("\n" + "="*65)
    print("  CONVERGENCE SUMMARY")
    print("="*65)
    if converged_N_uniform:
        r = next(x for x in sweep_results if x["N"] == converged_N_uniform)
        print(f"  Uniform sampling  : converged at N={converged_N_uniform}  "
              f"Re_rec={r['Re_rec']:.2f}  Error={r['error']:.2f}%")
    else:
        print("  Uniform sampling  : did NOT converge within N=100")

    if converged_N_wake:
        r = next(x for x in wake_results if x["N"] == converged_N_wake)
        print(f"  Wake sampling     : converged at N={converged_N_wake}  "
              f"Re_rec={r['Re_rec']:.2f}  Error={r['error']:.2f}%")
    else:
        print("  Wake sampling     : did NOT converge within N=100")

    print("="*65)


if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
#
# =================================================================
#   ME4222E — Problem 3: Inverse PINN
#   True Reynolds number: Re = 100
# =================================================================
#
# [A] Training forward PINN to generate synthetic observations...
#   [Forward Re=100] ep  1000  loss=8.1044e-03  pde=5.5221e-03  bc=2.5824e-04  t=23.2s
#   [Forward Re=100] ep  2000  loss=3.9355e-03  pde=3.0075e-03  bc=9.2803e-05  t=47.2s
#   [Forward Re=100] ep  3000  loss=2.1819e-03  pde=1.7236e-03  bc=4.5827e-05  t=69.8s
#
# ────────────────────────────────────────────────────────────
#   Forward PINN  Re=100  (Ground Truth)
# ────────────────────────────────────────────────────────────
# [B] Inverse PINN — N-sweep with UNIFORM sampling
#
#   N = 10 (uniform)
#   [Uniform N=10] ep  1000  total=6.3422e-03  Re_pred=37.23  t=24.2s
#   [Uniform N=10] ep  2000  total=3.6215e-03  Re_pred=48.52  t=48.4s
#   [Uniform N=10] ep  3000  total=2.3093e-03  Re_pred=71.18  t=72.2s
#   [Uniform N=10] ep  4000  total=1.7156e-03  Re_pred=105.70  t=95.8s
#   >> N=10  Re_rec=105.70  Error=5.70%  Loss=1.7156e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=10
# ────────────────────────────────────────────────────────────
#   *** CONVERGED at N=10 (uniform) ***
#
# ────────────────────────────────────────────────────────────
#   Inverse PINN  Uniform  N=10  Re_rec=105.7
# ────────────────────────────────────────────────────────────
#   N = 20 (uniform)
#   [Uniform N=20] ep  1000  total=9.5116e-03  Re_pred=73.61  t=24.0s
#   [Uniform N=20] ep  2000  total=5.0064e-03  Re_pred=81.54  t=47.8s
#   [Uniform N=20] ep  3000  total=1.8479e-03  Re_pred=70.58  t=71.6s
#   [Uniform N=20] ep  4000  total=1.6360e-03  Re_pred=83.36  t=95.7s
#   >> N=20  Re_rec=83.36  Error=16.64%  Loss=1.6360e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=20
# ────────────────────────────────────────────────────────────
#   N = 30 (uniform)
#   [Uniform N=30] ep  1000  total=1.2265e-02  Re_pred=59.21  t=23.6s
#   [Uniform N=30] ep  2000  total=5.3963e-03  Re_pred=100.41  t=47.2s
#   [Uniform N=30] ep  3000  total=1.7310e-03  Re_pred=141.39  t=70.9s
#   [Uniform N=30] ep  4000  total=1.5630e-03  Re_pred=150.17  t=94.9s
#   >> N=30  Re_rec=150.17  Error=50.17%  Loss=1.5630e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=30
# ────────────────────────────────────────────────────────────
#   N = 40 (uniform)
#   [Uniform N=40] ep  1000  total=8.4658e-03  Re_pred=61.46  t=25.8s
#   [Uniform N=40] ep  2000  total=3.6022e-03  Re_pred=76.23  t=49.6s
#   [Uniform N=40] ep  3000  total=2.0621e-03  Re_pred=89.65  t=73.5s
#   [Uniform N=40] ep  4000  total=1.8428e-03  Re_pred=104.09  t=97.3s
#   >> N=40  Re_rec=104.09  Error=4.09%  Loss=1.8428e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=40
# ────────────────────────────────────────────────────────────
#   N = 50 (uniform)
#   [Uniform N=50] ep  1000  total=1.0147e-02  Re_pred=61.97  t=23.7s
#   [Uniform N=50] ep  2000  total=7.2679e-03  Re_pred=104.49  t=47.5s
#   [Uniform N=50] ep  3000  total=2.3789e-03  Re_pred=191.47  t=71.0s
#   [Uniform N=50] ep  4000  total=2.0161e-03  Re_pred=229.54  t=94.6s
#   >> N=50  Re_rec=229.54  Error=129.54%  Loss=2.0161e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=50
# ────────────────────────────────────────────────────────────
#   N = 60 (uniform)
#   [Uniform N=60] ep  1000  total=2.4158e-02  Re_pred=71.66  t=23.6s
#   [Uniform N=60] ep  2000  total=7.8295e-03  Re_pred=67.00  t=47.2s
#   [Uniform N=60] ep  3000  total=1.9160e-03  Re_pred=83.15  t=70.9s
#   [Uniform N=60] ep  4000  total=2.1339e-03  Re_pred=100.93  t=95.2s
#   >> N=60  Re_rec=100.93  Error=0.93%  Loss=2.1339e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=60
# ────────────────────────────────────────────────────────────
#   N = 70 (uniform)
#   [Uniform N=70] ep  1000  total=1.4031e-02  Re_pred=73.46  t=23.9s
#   [Uniform N=70] ep  2000  total=6.1394e-03  Re_pred=84.33  t=47.7s
#   [Uniform N=70] ep  3000  total=1.9798e-03  Re_pred=110.10  t=71.5s
#   [Uniform N=70] ep  4000  total=1.6281e-03  Re_pred=136.90  t=95.4s
#   >> N=70  Re_rec=136.90  Error=36.90%  Loss=1.6281e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=70
# ────────────────────────────────────────────────────────────
#   N = 80 (uniform)
#   [Uniform N=80] ep  1000  total=9.9515e-03  Re_pred=52.50  t=24.1s
#   [Uniform N=80] ep  2000  total=6.7475e-03  Re_pred=75.31  t=48.0s
#   [Uniform N=80] ep  3000  total=1.9062e-03  Re_pred=95.16  t=71.9s
#   [Uniform N=80] ep  4000  total=3.2416e-03  Re_pred=106.09  t=96.7s
#   >> N=80  Re_rec=106.09  Error=6.09%  Loss=3.2416e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=80
# ────────────────────────────────────────────────────────────
#   N = 90 (uniform)
#   [Uniform N=90] ep  1000  total=1.1514e-02  Re_pred=62.07  t=27.9s
#   [Uniform N=90] ep  2000  total=1.0070e-02  Re_pred=87.57  t=51.7s
#   [Uniform N=90] ep  3000  total=4.4545e-03  Re_pred=101.02  t=75.5s
#   [Uniform N=90] ep  4000  total=1.6790e-03  Re_pred=104.47  t=99.4s
#   >> N=90  Re_rec=104.47  Error=4.47%  Loss=1.6790e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=90
# ────────────────────────────────────────────────────────────
#   N = 100 (uniform)
#   [Uniform N=100] ep  1000  total=7.5020e-03  Re_pred=59.71  t=23.7s
#   [Uniform N=100] ep  2000  total=1.7541e-02  Re_pred=72.76  t=47.7s
#   [Uniform N=100] ep  3000  total=3.0982e-03  Re_pred=86.87  t=71.5s
#   [Uniform N=100] ep  4000  total=1.8267e-03  Re_pred=93.88  t=95.3s
#   >> N=100  Re_rec=93.88  Error=6.12%  Loss=1.8267e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Uniform N=100
# ────────────────────────────────────────────────────────────
# [C] Inverse PINN — N-sweep with WAKE-CLUSTERED sampling
#
#   N = 10 (wake-clustered)
#   [Wake N=10] ep  1000  total=6.8973e-03  Re_pred=66.01  t=23.7s
#   [Wake N=10] ep  2000  total=4.9446e-03  Re_pred=57.66  t=47.5s
#   [Wake N=10] ep  3000  total=6.6248e-03  Re_pred=62.99  t=71.5s
#   [Wake N=10] ep  4000  total=3.4028e-03  Re_pred=81.14  t=95.2s
#   >> N=10  Re_rec=81.14  Error=18.86%  Loss=3.4028e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=10
# ────────────────────────────────────────────────────────────
#   N = 20 (wake-clustered)
#   [Wake N=20] ep  1000  total=1.1051e-02  Re_pred=59.36  t=24.3s
#   [Wake N=20] ep  2000  total=3.1987e-03  Re_pred=63.53  t=48.2s
#   [Wake N=20] ep  3000  total=3.8717e-03  Re_pred=75.29  t=72.1s
#   [Wake N=20] ep  4000  total=2.1241e-03  Re_pred=109.71  t=96.3s
#   >> N=20  Re_rec=109.71  Error=9.71%  Loss=2.1241e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=20
# ────────────────────────────────────────────────────────────
#   *** CONVERGED at N=20 (wake) ***
#
# ────────────────────────────────────────────────────────────
#   Inverse PINN  Wake  N=20  Re_rec=109.7
# ────────────────────────────────────────────────────────────
#   N = 30 (wake-clustered)
#   [Wake N=30] ep  1000  total=1.0590e-02  Re_pred=56.98  t=23.5s
#   [Wake N=30] ep  2000  total=6.4820e-03  Re_pred=46.53  t=46.9s
#   [Wake N=30] ep  3000  total=3.2038e-03  Re_pred=51.16  t=70.6s
#   [Wake N=30] ep  4000  total=1.9088e-03  Re_pred=91.00  t=94.4s
#   >> N=30  Re_rec=91.00  Error=9.00%  Loss=1.9088e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=30
# ────────────────────────────────────────────────────────────
#   N = 40 (wake-clustered)
#   [Wake N=40] ep  1000  total=8.5262e-03  Re_pred=46.74  t=28.3s
#   [Wake N=40] ep  2000  total=1.0757e-02  Re_pred=50.45  t=51.8s
#   [Wake N=40] ep  3000  total=1.9588e-03  Re_pred=63.89  t=75.4s
#   [Wake N=40] ep  4000  total=1.7222e-03  Re_pred=116.67  t=99.0s
#   >> N=40  Re_rec=116.67  Error=16.67%  Loss=1.7222e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=40
# ────────────────────────────────────────────────────────────
#   N = 50 (wake-clustered)
#   [Wake N=50] ep  1000  total=1.0176e-02  Re_pred=67.99  t=24.0s
#   [Wake N=50] ep  2000  total=6.4354e-03  Re_pred=68.61  t=47.8s
#   [Wake N=50] ep  3000  total=1.9924e-03  Re_pred=86.64  t=71.9s
#   [Wake N=50] ep  4000  total=1.6309e-03  Re_pred=156.82  t=95.5s
#   >> N=50  Re_rec=156.82  Error=56.82%  Loss=1.6309e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=50
# ────────────────────────────────────────────────────────────
#   N = 60 (wake-clustered)
#   [Wake N=60] ep  1000  total=1.1407e-02  Re_pred=68.82  t=23.6s
#   [Wake N=60] ep  2000  total=6.9757e-03  Re_pred=57.11  t=47.2s
#   [Wake N=60] ep  3000  total=1.9435e-03  Re_pred=64.72  t=71.1s
#   [Wake N=60] ep  4000  total=2.2770e-03  Re_pred=84.43  t=94.8s
#   >> N=60  Re_rec=84.43  Error=15.57%  Loss=2.2770e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=60
# ────────────────────────────────────────────────────────────
#   N = 70 (wake-clustered)
#   [Wake N=70] ep  1000  total=9.1067e-03  Re_pred=73.98  t=24.0s
#   [Wake N=70] ep  2000  total=2.2413e-03  Re_pred=65.92  t=47.9s
#   [Wake N=70] ep  3000  total=1.8710e-03  Re_pred=91.97  t=71.8s
#   [Wake N=70] ep  4000  total=1.5795e-03  Re_pred=131.47  t=95.7s
#   >> N=70  Re_rec=131.47  Error=31.47%  Loss=1.5795e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=70
# ────────────────────────────────────────────────────────────
#   N = 80 (wake-clustered)
#   [Wake N=80] ep  1000  total=2.9475e-02  Re_pred=54.17  t=23.9s
#   [Wake N=80] ep  2000  total=3.2840e-03  Re_pred=57.43  t=47.7s
#   [Wake N=80] ep  3000  total=2.5662e-03  Re_pred=81.33  t=71.4s
#   [Wake N=80] ep  4000  total=1.8186e-03  Re_pred=143.10  t=94.9s
#   >> N=80  Re_rec=143.10  Error=43.10%  Loss=1.8186e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=80
# ────────────────────────────────────────────────────────────
#   N = 90 (wake-clustered)
#   [Wake N=90] ep  1000  total=2.3326e-02  Re_pred=67.75  t=24.9s
#   [Wake N=90] ep  2000  total=4.8578e-03  Re_pred=48.74  t=48.6s
#   [Wake N=90] ep  3000  total=1.9399e-03  Re_pred=69.95  t=72.5s
#   [Wake N=90] ep  4000  total=1.5348e-03  Re_pred=118.09  t=96.4s
#   >> N=90  Re_rec=118.09  Error=18.09%  Loss=1.5348e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=90
# ────────────────────────────────────────────────────────────
#   N = 100 (wake-clustered)
#   [Wake N=100] ep  1000  total=1.5517e-02  Re_pred=77.20  t=23.9s
#   [Wake N=100] ep  2000  total=5.4347e-03  Re_pred=63.14  t=47.8s
#   [Wake N=100] ep  3000  total=9.8543e-03  Re_pred=66.94  t=71.6s
#   [Wake N=100] ep  4000  total=1.8773e-03  Re_pred=99.28  t=95.6s
#   >> N=100  Re_rec=99.28  Error=0.72%  Loss=1.8773e-03
#
# ────────────────────────────────────────────────────────────
#   Loss History: Wake N=100
# ────────────────────────────────────────────────────────────
# [D] Generating summary plots and tables...
#
# ────────────────────────────────────────────────────────────
#   Uniform Sampling: Re Convergence vs N
# ────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────
#   Sampling Strategy Comparison
# ────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────
#   Observation Point Locations
# ────────────────────────────────────────────────────────────
# =================================================================
#   TABLE 1 — Uniform Sampling: N vs Recovered Re
# =================================================================
#   N  Recovered Re  % Error  Final Loss Strategy
#  10      105.7024   5.7024      0.0017  uniform
#  20       83.3631  16.6369      0.0016  uniform
#  30      150.1719  50.1719      0.0016  uniform
#  40      104.0885   4.0885      0.0018  uniform
#  50      229.5351 129.5351      0.0020  uniform
#  60      100.9325   0.9325      0.0021  uniform
#  70      136.8971  36.8971      0.0016  uniform
#  80      106.0854   6.0854      0.0032  uniform
#  90      104.4736   4.4736      0.0017  uniform
# 100       93.8847   6.1153      0.0018  uniform
#
# =================================================================
#   TABLE 2 — Wake-Clustered Sampling: N vs Recovered Re
# =================================================================
#   N  Recovered Re  % Error  Final Loss Strategy
#  10       81.1367  18.8633      0.0034     wake
#  20      109.7127   9.7127      0.0021     wake
#  30       90.9990   9.0010      0.0019     wake
#  40      116.6743  16.6743      0.0017     wake
#  50      156.8211  56.8211      0.0016     wake
#  60       84.4257  15.5743      0.0023     wake
#  70      131.4720  31.4720      0.0016     wake
#  80      143.1018  43.1018      0.0018     wake
#  90      118.0924  18.0924      0.0015     wake
# 100       99.2840   0.7160      0.0019     wake
#
# [Rendered table — Uniform]
# <style type="text/css">
# #T_548d1_row5_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_548d1">
#   <caption>Uniform Sampling Results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_548d1_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_548d1_level0_col1" class="col_heading level0 col1" >Recovered Re</th>
#       <th id="T_548d1_level0_col2" class="col_heading level0 col2" >% Error</th>
#       <th id="T_548d1_level0_col3" class="col_heading level0 col3" >Final Loss</th>
#       <th id="T_548d1_level0_col4" class="col_heading level0 col4" >Strategy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_548d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_548d1_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_548d1_row0_col1" class="data row0 col1" >105.70</td>
#       <td id="T_548d1_row0_col2" class="data row0 col2" >5.70%</td>
#       <td id="T_548d1_row0_col3" class="data row0 col3" >1.7156e-03</td>
#       <td id="T_548d1_row0_col4" class="data row0 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_548d1_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_548d1_row1_col1" class="data row1 col1" >83.36</td>
#       <td id="T_548d1_row1_col2" class="data row1 col2" >16.64%</td>
#       <td id="T_548d1_row1_col3" class="data row1 col3" >1.6360e-03</td>
#       <td id="T_548d1_row1_col4" class="data row1 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_548d1_row2_col0" class="data row2 col0" >30</td>
#       <td id="T_548d1_row2_col1" class="data row2 col1" >150.17</td>
#       <td id="T_548d1_row2_col2" class="data row2 col2" >50.17%</td>
#       <td id="T_548d1_row2_col3" class="data row2 col3" >1.5630e-03</td>
#       <td id="T_548d1_row2_col4" class="data row2 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_548d1_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_548d1_row3_col1" class="data row3 col1" >104.09</td>
#       <td id="T_548d1_row3_col2" class="data row3 col2" >4.09%</td>
#       <td id="T_548d1_row3_col3" class="data row3 col3" >1.8428e-03</td>
#       <td id="T_548d1_row3_col4" class="data row3 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_548d1_row4_col0" class="data row4 col0" >50</td>
#       <td id="T_548d1_row4_col1" class="data row4 col1" >229.54</td>
#       <td id="T_548d1_row4_col2" class="data row4 col2" >129.54%</td>
#       <td id="T_548d1_row4_col3" class="data row4 col3" >2.0161e-03</td>
#       <td id="T_548d1_row4_col4" class="data row4 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_548d1_row5_col0" class="data row5 col0" >60</td>
#       <td id="T_548d1_row5_col1" class="data row5 col1" >100.93</td>
#       <td id="T_548d1_row5_col2" class="data row5 col2" >0.93%</td>
#       <td id="T_548d1_row5_col3" class="data row5 col3" >2.1339e-03</td>
#       <td id="T_548d1_row5_col4" class="data row5 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_548d1_row6_col0" class="data row6 col0" >70</td>
#       <td id="T_548d1_row6_col1" class="data row6 col1" >136.90</td>
#       <td id="T_548d1_row6_col2" class="data row6 col2" >36.90%</td>
#       <td id="T_548d1_row6_col3" class="data row6 col3" >1.6281e-03</td>
#       <td id="T_548d1_row6_col4" class="data row6 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_548d1_row7_col0" class="data row7 col0" >80</td>
#       <td id="T_548d1_row7_col1" class="data row7 col1" >106.09</td>
#       <td id="T_548d1_row7_col2" class="data row7 col2" >6.09%</td>
#       <td id="T_548d1_row7_col3" class="data row7 col3" >3.2416e-03</td>
#       <td id="T_548d1_row7_col4" class="data row7 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_548d1_row8_col0" class="data row8 col0" >90</td>
#       <td id="T_548d1_row8_col1" class="data row8 col1" >104.47</td>
#       <td id="T_548d1_row8_col2" class="data row8 col2" >4.47%</td>
#       <td id="T_548d1_row8_col3" class="data row8 col3" >1.6790e-03</td>
#       <td id="T_548d1_row8_col4" class="data row8 col4" >uniform</td>
#     </tr>
#     <tr>
#       <th id="T_548d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_548d1_row9_col0" class="data row9 col0" >100</td>
#       <td id="T_548d1_row9_col1" class="data row9 col1" >93.88</td>
#       <td id="T_548d1_row9_col2" class="data row9 col2" >6.12%</td>
#       <td id="T_548d1_row9_col3" class="data row9 col3" >1.8267e-03</td>
#       <td id="T_548d1_row9_col4" class="data row9 col4" >uniform</td>
#     </tr>
#   </tbody>
# </table>
# [Rendered table — Wake-Clustered]
# <style type="text/css">
# #T_889b7_row9_col2 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_889b7">
#   <caption>Wake-Clustered Sampling Results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_889b7_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_889b7_level0_col1" class="col_heading level0 col1" >Recovered Re</th>
#       <th id="T_889b7_level0_col2" class="col_heading level0 col2" >% Error</th>
#       <th id="T_889b7_level0_col3" class="col_heading level0 col3" >Final Loss</th>
#       <th id="T_889b7_level0_col4" class="col_heading level0 col4" >Strategy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_889b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_889b7_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_889b7_row0_col1" class="data row0 col1" >81.14</td>
#       <td id="T_889b7_row0_col2" class="data row0 col2" >18.86%</td>
#       <td id="T_889b7_row0_col3" class="data row0 col3" >3.4028e-03</td>
#       <td id="T_889b7_row0_col4" class="data row0 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_889b7_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_889b7_row1_col1" class="data row1 col1" >109.71</td>
#       <td id="T_889b7_row1_col2" class="data row1 col2" >9.71%</td>
#       <td id="T_889b7_row1_col3" class="data row1 col3" >2.1241e-03</td>
#       <td id="T_889b7_row1_col4" class="data row1 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_889b7_row2_col0" class="data row2 col0" >30</td>
#       <td id="T_889b7_row2_col1" class="data row2 col1" >91.00</td>
#       <td id="T_889b7_row2_col2" class="data row2 col2" >9.00%</td>
#       <td id="T_889b7_row2_col3" class="data row2 col3" >1.9088e-03</td>
#       <td id="T_889b7_row2_col4" class="data row2 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_889b7_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_889b7_row3_col1" class="data row3 col1" >116.67</td>
#       <td id="T_889b7_row3_col2" class="data row3 col2" >16.67%</td>
#       <td id="T_889b7_row3_col3" class="data row3 col3" >1.7222e-03</td>
#       <td id="T_889b7_row3_col4" class="data row3 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_889b7_row4_col0" class="data row4 col0" >50</td>
#       <td id="T_889b7_row4_col1" class="data row4 col1" >156.82</td>
#       <td id="T_889b7_row4_col2" class="data row4 col2" >56.82%</td>
#       <td id="T_889b7_row4_col3" class="data row4 col3" >1.6309e-03</td>
#       <td id="T_889b7_row4_col4" class="data row4 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_889b7_row5_col0" class="data row5 col0" >60</td>
#       <td id="T_889b7_row5_col1" class="data row5 col1" >84.43</td>
#       <td id="T_889b7_row5_col2" class="data row5 col2" >15.57%</td>
#       <td id="T_889b7_row5_col3" class="data row5 col3" >2.2770e-03</td>
#       <td id="T_889b7_row5_col4" class="data row5 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_889b7_row6_col0" class="data row6 col0" >70</td>
#       <td id="T_889b7_row6_col1" class="data row6 col1" >131.47</td>
#       <td id="T_889b7_row6_col2" class="data row6 col2" >31.47%</td>
#       <td id="T_889b7_row6_col3" class="data row6 col3" >1.5795e-03</td>
#       <td id="T_889b7_row6_col4" class="data row6 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_889b7_row7_col0" class="data row7 col0" >80</td>
#       <td id="T_889b7_row7_col1" class="data row7 col1" >143.10</td>
#       <td id="T_889b7_row7_col2" class="data row7 col2" >43.10%</td>
#       <td id="T_889b7_row7_col3" class="data row7 col3" >1.8186e-03</td>
#       <td id="T_889b7_row7_col4" class="data row7 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_889b7_row8_col0" class="data row8 col0" >90</td>
#       <td id="T_889b7_row8_col1" class="data row8 col1" >118.09</td>
#       <td id="T_889b7_row8_col2" class="data row8 col2" >18.09%</td>
#       <td id="T_889b7_row8_col3" class="data row8 col3" >1.5348e-03</td>
#       <td id="T_889b7_row8_col4" class="data row8 col4" >wake</td>
#     </tr>
#     <tr>
#       <th id="T_889b7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_889b7_row9_col0" class="data row9 col0" >100</td>
#       <td id="T_889b7_row9_col1" class="data row9 col1" >99.28</td>
#       <td id="T_889b7_row9_col2" class="data row9 col2" >0.72%</td>
#       <td id="T_889b7_row9_col3" class="data row9 col3" >1.8773e-03</td>
#       <td id="T_889b7_row9_col4" class="data row9 col4" >wake</td>
#     </tr>
#   </tbody>
# </table>
# =================================================================
#   CONVERGENCE SUMMARY
# =================================================================
#   Uniform sampling  : converged at N=10  Re_rec=105.70  Error=5.70%
#   Wake sampling     : converged at N=20  Re_rec=109.71  Error=9.71%
# =================================================================
